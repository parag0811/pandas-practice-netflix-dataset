# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
df = pd.read_csv('../data/netflix_titles.csv')

# %% [markdown]
# ## Basics

# %%
# Load dataset, check shape, info, and missing values.
df.head()
# df.shape
df.info
df.isnull().sum() # Sum of all null values
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Find how many movies vs TV shows
df.head(10)
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
# Count how many titles released each year
df.head()
df['release_year'].value_counts() # Each title has unique id so it automatically gives no of titles each year.
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1961       1
# 1925       1
# 1959       1
# 1966       1
# 1947       1
# Name: count, Length: 74, dtype: int64

# %% [markdown]
# ### Plots in matplotlib / seaborn

# %%
import numpy as np 
# Releases per year
df.head()
yearly_counts = df.groupby('release_year').size().reset_index(name = 'count')
yearly_counts
plt.figure(figsize=(14,6))
sns.barplot(x='release_year',  y = 'count', data=  yearly_counts)
# Out:
# <Axes: xlabel='release_year', ylabel='count'>

# %%
# Movies vs TV shows count

count = df['type'].value_counts()
plt.figure(figsize=(12,6))    
plt.pie(count, labels=count.index)
plt.title("Movie vs TV Show")
# Out:
# Text(0.5, 1.0, 'Movie vs TV Show')

# %%
content_per_country = df['country'].value_counts().head(10).reset_index(name = 'content')
content_per_country

plt.figure(figsize=(12,6))
sns.barplot(x = 'content', y= 'country',data=content_per_country, palette='viridis')
# Out:
# C:\Users\parag\AppData\Local\Temp\ipykernel_9048\2242460290.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'content', y= 'country',data=content_per_country, palette='viridis')
# <Axes: xlabel='content', ylabel='country'>

# %%
plt.hist(df['release_year'], bins=df['release_year'].nunique(), edgecolor='black')
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.title('Distribution of Netflix Releases by Year')
# Out:
# Text(0.5, 1.0, 'Distribution of Netflix Releases by Year')
